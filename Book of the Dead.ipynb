# %% [markdown]
# # 𓁫 𓁣 𓅔  𓁟 𓅊 𓁡 𓀤 𓀠 𓀀 𓂀 𓆣 Book of the Dead 𓂀 𓆣 𓁫 𓁣 𓅔 𓅊 𓀍 𓁢 𓁚 𓁟  𓀤 𓀠 𓀀 𓂀𓆣

# %% [markdown]
# ## Introduction:
#
#  Welcome to ancient Egypt's afterlife. Where Pharaons use the Book of the Dead to win eternal life.
# In the Book of the Dead, it is difficult to say when the magic starts and when it ends. In other words, magic and religion go hand in hand. Magic was used as praying to the gods at the same time controlling them. Indeed, mastering the spelling of a book is the secret for heaven, despite your behaviors during your life.
#
#     The goal of this game is to win eternal life on three stages:
#
#     Stage 1: 🧟‍ Mummification 🧟‍♂️
#     Stage 2: 🪦  Afterlife   🪦
#     Stage 3: ⚖️   Judgment    ⚖️
#
#
#     Before to start playing Please check the TED link: Introduction to the Book of the death.
#
#
#     https://www.youtube.com/watch?v=1yv_MXNYbAo

# %%
'''
Hult Internation Business School San Francisco 
Created on 1/21/2022 by Abdelmohssin Elyounssi
 

The Book of the Dead is an educational game aimes to teach the students 
the stages of after life in the Pharones cosmogonie. 

'''
# 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓 𓅓  𓅓 𓅓

### In this game, I tried to create maximum soft cod and functions 
## to make my cod as independent building blocks if one block got an error 
## will not affects others.

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 

## Every question i gave the possibility to the user to stop the game 


# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣

## Importing packages for the game 
import time 
import sys


# Creating mission impossible writing  
#sleep to give the game a better flow
def mi(str):
    for letters in str:
        sys.stdout.write(letters)
#sleep to give the game a better flow       
        sys.stdout.flush()
        time.sleep(0.04)

# Creating hilogriphic animation 

print(f"""
{' 𓂀 𓆣 ' * 12}\n""")    

# Creating soft cod for enter

def enter():
    input(prompt="> Please press enter to continue...\n")
  
  
mi(f"""
The Book of the Death is the map for Phraones to win the eternal life 
Your mission in this game is to become eternal 
but befor you have to die 𓀿 𓀿 𓀿

""")  

print(f"""
{' 𓂀 𓆣 ' * 12}\n""")

enter()

# Asking for dead name input to start the game

dead_name = input(prompt='What\'s your name?  ').capitalize()

# Asking for dead name age using try/except

global age
while True:
    try:
        age = int(input("Please enter your age: "))
        break
    except ValueError:
        print("Oops!  That was no valid number.  Try again...")

# Dotted-line spacing

print(f"""
{'𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀' * 2}\n""")

# Welcoming the user 

mi(f"""
Welcome {dead_name}. I am the God  𓁛 RE 𓁛  SUN GOD 𓁛

I will help you to make it to enternal life\n """)

# Dotted-line spacing

print(f"""
{'𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀' * 2}\n""")

mi(f""" 

{dead_name.capitalize() }, I know {age} year old is too young to die.

But, if you want to become etrenal you have first to be 

𓁀 𓁀 Mummifaied 𓁀 𓁀

    """)        

print(f"""
{'𓁀 𓁀 ' * 12}""")

# 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 
# The first question in mummification room 

def Mummification1():

    enter()
    #Give the flexibility to the user to stope the game 
    print("Press A to go to mummification room.")
    print("Press B to stop the game.")
    print(f"""{'𓁀 𓁀 ' * 12}\n""")
    
    choice = input("> ").casefold()
    
    
    if choice in  ['a','mummification','go','room']:
        print(f"""{'𓁀 𓁀 ' * 12}\n""")
        print("Then you must answer 3 questions in mummification room.\n") 
    
        print(f"""{'𓁀 𓁀 ' * 12}""")
       
        print( 
"""
First question 

Wich organs do we have to keep without mummification?

1) Eyes.
2) Heart.
3) Brain.
        
""") 
        
        choice = input("> ").casefold()
        # Start of nested conditional
        if choice in ['1','3','eyes','eye','brain','e','b']:
            print("That's incorrect.")
            
            fail1()
        #Intuitives choices     
        elif choice in ['2','heart','h']:
            mi("That's correct! Please enjoy the second question in mummification room !")
            
            Mummification2()
            
        # End of nested conditional
        #Else to pick up human error 
        else:
            print("Invalid entry. Please try again.\n")
            enter()
            Mummification1()
        
     # Choice to end the game   
    elif choice in ['b', 'stop','game']:
            game_is_over()

#Extra else to pick up human error    
    
    else:
        print("Invalid entry. Please try again.\n")
        enter()
        Mummification1()

## 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀         
## 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 
#The second question in mummification room 

def Mummification2():
    
    enter()
    #Give the flexibility to the user to stope the game 
    print("Press A to stay in mummification room.")
    print("Press B to stop the game.")
    print(f"""{'𓁀 𓁀 ' * 12}\n""")
    choice = input(prompt= "> ").casefold()
    
    
    if choice =='a':
        
        print("Then you must answer the second question in mummification room.\n") 
        print(f"""{'𓁀 𓁀 ' * 12}\n""")
        print( 
"""
Second question 

What is the product used to protect the mummy?

1) Nitrate.
2) Sodium. 
        
""") 
        choice = input("> ").casefold()
        
        
        # Start of nested conditional
        
        if choice in ['2','sodium','s']:
            print("That's incorrect.")
            
            fail1()
        #Intuitives choices   
        elif choice in ['1','nitrate','n']:
            mi("That's correct! Please enjoy the third question!")
            Mummification3()
        #Else to pick up human error    
        else:
            print("Invalid entry. Please try again.\n")
            enter()
            Mummification2()   
            
        # End of nested conditional
        
    # Choice to end the game    
    elif choice in ['b', 'stop','game']:
        game_is_over()
    
    else:
        print("Invalid entry. Please try again.\n")
        enter()
        Mummification2()
        
### 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀       
### 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀
### 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 
#the third question in mummification room 

def Mummification3():
    
    enter()
    #Give the flexibility to the user to stope the game 
    print("Press A to stay in mummification room.")
    print("Press B to stop the game.")
    print(f"""{'𓁀 𓁀 ' * 12}\n""")
    choice = input(prompt="> ").casefold()
    
    
    if choice in  ['a','mummification','go','stay','room']:
        
        print("Then you must answer the last question in mummification room.\n") 
        print(f"""{'𓁀 𓁀 ' * 12}\n""")
        print( 
"""
Third question 

Why the scarab 𓆣 𓆣 𓆣 is important?

1) Protect the Mommy against the worms.
2) Stand against monsters.
3) To prevent the heart, to tell the truth. 
        
""") 
        choice = input(prompt="> ").casefold()
        
        
        # Start of nested conditional
        if choice in ['2','1','protect','mommy','against','worms','stand','monster','s','p']:
            print("That's incorrect.")
            
            fail1()
         #Intuitives choices   
        elif choice in ['3','prevent','heart','tell','truth','t']:
            mi("That's correct! Please enjoy the After life Room!")
            
            After_life1()
        #Else to pick up human error    
        else:
            print("Invalid entry. Please try again.\n")
            enter()
            Mummification3()     
        # End of nested conditional
        
    # Choice to end the game     
    elif choice in ['b', 'stop','game']:
        game_is_over()
    #Else to pick up human error
    else:
        print("Invalid entry. Please try again.\n")
        enter()
        Mummification2()

#𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀
#The first question in after life room 

def After_life1():
# countdown for oppning the door     
    countdown()
    enter()
    #Give the flexibility to the user to stope the game 
    print("Press A to go to after life room.")
    print("Press B to stop the game.")
    print(f"""{'𓂀 𓂀 ' * 12}\n""")
    choice = input(prompt="> ").casefold()
    #Intuitives choices
    if choice in  ['a','after', 'life','go','rooms']:
        print(f"""{'𓂀 𓂀 ' * 12}\n""")
        
        mi("Then you must answer 2 questions in after life room.\n") 
        
        print(f"""{'𓂀 𓂀 ' * 12}\n""")
        print( 
"""
First question

You are in front of the Osiris God ..!!!!! 
Asking you, if you comited sins ??

What do you do?

1) Appropriate spelling.
2) Use your scarab.
3) Run

        
""") 
        choice = input(prompt="> ").casefold()
       
        # Start of nested conditional
        if choice in ['1', 'appropriate','spelling','a']:
            mi("That's correct! Please enjoy the second question in after life room!")
            
            After_life2()
        #Intuitives choices    
        elif choice in ['2','3','run','use','your','scarab','u','r']:
            print("That's incorrect.")
            fail2()
        #Else to pick up human error    
        else:
            
            print("Invalid entry. Please try again.\n")
            enter()
            After_life1()
            
        # End of nested conditional
        
    # Choice to end the game     
    elif choice in ['b', 'stop','game']:
        game_is_over()
    #Else to pick up human error
    else:
        print("Invalid entry. Please try again.\n")
        enter()
        After_life1()
#𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀   
#𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀 𓂀
#The second question in after life room 

def After_life2():
    
    enter()
    #Give the flexibility to the user to stope the game 
    print("Press A to stay in after life room.")
    print("Press B to stop the game.")
    print(f"""{'𓂀 𓂀 ' * 12}\n""")
    choice = input(prompt="> ").casefold()
    #Intuitives choices
    if choice in  ['a','after life','stay','room']:
        
        mi("Then you must answer the second question.\n") 
        print(f"""{'𓂀 𓂀 ' * 12}\n""")
        print( 
"""
Second question

You are in front of the 𓁦 MAAT 𓁦 GOD of the 𓁦 TRUTH and JUSTICE 𓁦 . 

Asking you, if you lived a perfect life ?

What do you do?

1) Appropriate spelling.
2) Confess your sins.
3) Negotiate.
4) Declar your innocent and hope that scarab will not betray you.


        
""") 
        choice = input("> ").casefold()
        
        # Start of nested conditional
        if choice in ['4','declar','innocent','hope','scarb','not','betray','d']:
            mi("That's correct! Please enjoy the judjment room!")
            
            Judgment()
         #Intuitives choices   
        elif choice in ['1','2','3','appropriate','spelling','confess','sins','a','c','n']:
            print("That's incorrect.")
            fail2()
        #Else to pick up human error    
        else:
            
            print("Invalid entry. Please try again.\n")
            enter()
            After_life2()
            
        # End of nested conditional
        
     # Choice to end the game    
    elif choice in ['b', 'stop','game']:
        game_is_over()
    #Else to pick up human error
    else:
        print("Invalid entry. Please try again.\n")
        enter()
        After_life2()


# 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 
#The question in judgment room 

def Judgment():
# countdown for oppning the door    
    countdown()
    enter()
    #Give the flexibility to the user to stope the game 
    print("Press A to go to Judgment room.")
    print("Press B to stop the game.")
    print(f"""{'𓍝 𓍝 ' * 12}\n""")
    choice = input(prompt="> ").casefold()
    
    #Intuitives choices
    if choice in  ['a','judgment','go','room']:
        print(f"""{'𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀' * 2}\n""")
        mi("Then you must answer this question.\n") 
        print(f"""{'𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀' * 2}\n""")
        print( 
"""

You are in front of GOD 𓁢 𓁢 𓁢 ANUBIS 𓁢 𓁢 𓁢
Balancing your heart 𓍝 𓍝

If your heart is heavy it means you gain eternal life?

1) True.
2) False.

        
""") 
        choice = input(prompt="> ").casefold()
        
        # Start of nested conditional
        if choice in ['2','false','f']:
            mi("That's correct! Please enjoy your etrnel Life !")
            
            eternal_life()
        #Intuitives choices    
        elif choice in['1','truth','t']:
            print("That's incorrect.")
            
            fail3()
         #Else to pick up human error   
        else:
            
            print("Invalid entry. Please try again.\n")
            enter()
            Judgment()   
            
        # End of nested conditional
        
    # Choice to end the game     
    elif choice in ['b', 'stop','game']:
        game_is_over()    
    #Else to pick up human error
    else:
        print("Invalid entry. Please try again.\n")
        enter()
        Judgment()
        
# 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝 𓍝     
    
## 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 
# countdown for oppning the door 

def countdown():
    tme=5
    print('The door of the room will be open on 5 seconds...\n')
    while tme > 0:
        print(tme, end='...𓀤...𓀤...𓀤 ')
        time.sleep(1)
        tme -= 1
        if tme == 0:
            print(" Let's Go!!!! \n")
        else:
            print("... \n")

countdown()

## 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Fail function 1 for mummification room 

def fail1():
    
    print(f""" {fail1_text}""")
    
    mi(f"""{dead_name},would you like to play again, ? \n""")
    response = input(prompt="> Please write 'Yes/No'\n").casefold()
    #Intuitives choices
    yes_no = ['yes', 'no','y','n']
     #While loop to pick up human error
    while response not in yes_no:
        print("Invalid entry. Please try again.\n")
        print(f"""{dead_name},would you like to play again ? \n""")
        response = input(prompt="> Please write 'Yes/No'\n").casefold()
    
    if response == 'yes'or response == 'y':
        Mummification1()
        
    else:
        print(f""" 
         
         >>> Sorry {dead_name} <<<<
 
            {game_is_over_text}                                                                             
        
        \n""")
        
    return response

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Fail function 2 for after life room 

def fail2():
    
    print(f""" {fail2_text}""")
    
    mi(f"""{dead_name},would you like to play again, ? \n""")
    response = input(prompt="> Please write 'Yes/No'\n").casefold()
    #Intuitives choices
    yes_no = ['yes', 'no','y','n']
     #While loop to pick up human error
    while response not in yes_no:
        print("Invalid entry. Please try again.\n")
        print(f"""{dead_name},would you like to play again ? \n""")
        response = input(prompt="> Please write 'Yes/No'\n").casefold()
    
    if response == 'yes'or response == 'y':
        After_life1()
        
    else:
        print(f""" Sorry {dead_name}
 
            {game_is_over_text}                                                                             
        
        \n""")
        
    return response

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣     
# Fail function 3 for judgment room 

def fail3():
    
    print(f""" {fail3_text}""")
    mi(f"""{dead_name},would you like to play again, ? \n""")
    response = input(prompt="> Please write 'Yes/No'\n").casefold()
    #Intuitives choices
    yes_no = ['yes', 'no','y','n']
     #While loop to pick up human error
    while response not in yes_no:
        print("Invalid entry. Please try again.\n")
        print(f"""{dead_name},would you like to play again ? \n""")
        response = input(prompt="> Please write 'Yes/No'\n").casefold()
    
    if response == 'yes'or response == 'y':
        Judgment()
     # Choice to end the game    
    else:
        print(f""" Sorry {dead_name}
 
            {game_is_over_text}                                                                             
        
        \n""")
        
    return response

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Function of message game is over 

def game_is_over():  
    print (f""" 
           >>> Sorry {dead_name} <<<<
 
            {game_is_over_text}                                                                             
        
        \n""")
    
# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Function of message eternal life 

def eternal_life():
    
    print(etrenal_life_text)
    
    mi(f"""{dead_name},would you like to play again ? \n""")
    response = input(prompt="> Please write 'Yes/No'\n").casefold()
    #Intuitives choices
    yes_no = ['yes', 'no','y','n']
    
    #While loop to pick up human error
    while response not in yes_no:
        print("Invalid entry. Please try again.\n")
        print(f"""{dead_name}Would you like to play again ? \n""")
        replay = input(prompt="> Please write 'Yes/No'\n").casefold()
    
    if response == 'yes'or response == 'y':
        Mummification1()
     # Choice to end the game    
    else:
        print(f"""{dead_name}, Thank you \n""")
        
    return response 




# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Fail 1 text

fail1_text=(f""" 

>>> Sorry {dead_name} <<<<

███╗   ██╗ ██████╗     ███████╗████████╗███████╗██████╗ ███╗   ██╗ █████╗ ██╗         
████╗  ██║██╔═══██╗    ██╔════╝╚══██╔══╝██╔════╝██╔══██╗████╗  ██║██╔══██╗██║         
██╔██╗ ██║██║   ██║    █████╗     ██║   █████╗  ██████╔╝██╔██╗ ██║███████║██║         
██║╚██╗██║██║   ██║    ██╔══╝     ██║   ██╔══╝  ██╔══██╗██║╚██╗██║██╔══██║██║         
██║ ╚████║╚██████╔╝    ███████╗   ██║   ███████╗██║  ██║██║ ╚████║██║  ██║███████╗    
╚═╝  ╚═══╝ ╚═════╝     ╚══════╝   ╚═╝   ╚══════╝╚═╝  ╚═╝╚═╝  ╚═══╝╚═╝  ╚═╝╚══════╝    
 
 
██╗     ██╗███████╗███████╗
██║     ██║██╔════╝██╔════╝
██║     ██║█████╗  █████╗  
██║     ██║██╔══╝  ██╔══╝  
███████╗██║██║     ███████╗
╚══════╝╚═╝╚═╝     ╚══════╝
                         
 
 
███████╗ ██████╗ ██████╗     ██╗   ██╗ ██████╗ ██╗   ██╗
██╔════╝██╔═══██╗██╔══██╗    ╚██╗ ██╔╝██╔═══██╗██║   ██║
█████╗  ██║   ██║██████╔╝     ╚████╔╝ ██║   ██║██║   ██║
██╔══╝  ██║   ██║██╔══██╗      ╚██╔╝  ██║   ██║██║   ██║
██║     ╚██████╔╝██║  ██║       ██║   ╚██████╔╝╚██████╔╝
╚═╝      ╚═════╝ ╚═╝  ╚═╝       ╚═╝    ╚═════╝  ╚═════╝
""") 

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# fail 2 text 

fail2_text=(f"""

>>> Sorry {dead_name} <<<<

🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗██╗██╗     ██╗       ██████╗ ███████╗        
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██║██║     ██║       ██╔══██╗██╔════╝        
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║██║     ██║       ██████╔╝█████╗          
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║██║     ██║       ██╔══██╗██╔══╝          
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝██║███████╗███████╗  ██████╔╝███████╗        
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝ ╚═╝╚══════╝╚══════╝  ╚═════╝ ╚══════╝        
              
          
███████╗████████╗████████╗███████╗███╗   ██╗
██╔════╝╚══██╔══╝╚══██╔══╝██╔════╝████╗  ██║
█████╗     ██║      ██║   █████╗  ██╔██╗ ██║
██╔══╝     ██║      ██║   ██╔══╝  ██║╚██╗██║
███████╗   ██║      ██║   ███████╗██║ ╚████║
╚══════╝   ╚═╝      ╚═╝   ╚══════╝╚═╝  ╚═══╝
          
██████╗ ██╗   ██╗    ██████╗ ███████╗██████╗ ███████╗
██╔══██╗╚██╗ ██╔╝    ██╔══██╗██╔════╝██╔══██╗██╔════╝
██████╔╝ ╚████╔╝     ██████╔╝█████╗  ██████╔╝█████╗  
██╔══██╗  ╚██╔╝      ██╔═══╝ ██╔══╝  ██╔═══╝ ██╔══╝  
██████╔╝   ██║       ██║     ███████╗██║     ███████╗
╚═════╝    ╚═╝       ╚═╝     ╚══════╝╚═╝     ╚══════╝  

🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍🐍
""")

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Game is over text

game_is_over_text=(f"""

 ██████╗  █████╗ ███╗   ███╗███████╗    ██╗███████╗     ██████╗ ██╗   ██╗███████╗██████╗ 
██╔════╝ ██╔══██╗████╗ ████║██╔════╝    ██║██╔════╝    ██╔═══██╗██║   ██║██╔════╝██╔══██╗
██║  ███╗███████║██╔████╔██║█████╗      ██║███████╗    ██║   ██║██║   ██║█████╗  ██████╔╝
██║   ██║██╔══██║██║╚██╔╝██║██╔══╝      ██║╚════██║    ██║   ██║╚██╗ ██╔╝██╔══╝  ██╔══██╗
╚██████╔╝██║  ██║██║ ╚═╝ ██║███████╗    ██║███████║    ╚██████╔╝ ╚████╔╝ ███████╗██║  ██║
 ╚═════╝ ╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝    ╚═╝╚══════╝     ╚═════╝   ╚═══╝  ╚══════╝╚═╝  ╚═╝         
    """) 

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Fail 3 text 

fail3_text=(f""" 

>>> Sorry {dead_name} <<<<

🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗██╗██╗     ██╗       ██████╗ ███████╗        
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██║██║     ██║       ██╔══██╗██╔════╝        
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║██║     ██║       ██████╔╝█████╗          
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║██║     ██║       ██╔══██╗██╔══╝          
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝██║███████╗███████╗  ██████╔╝███████╗        
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝ ╚═╝╚══════╝╚══════╝  ╚═════╝ ╚══════╝        
              
          
███████╗████████╗████████╗███████╗███╗   ██╗
██╔════╝╚══██╔══╝╚══██╔══╝██╔════╝████╗  ██║
█████╗     ██║      ██║   █████╗  ██╔██╗ ██║
██╔══╝     ██║      ██║   ██╔══╝  ██║╚██╗██║
███████╗   ██║      ██║   ███████╗██║ ╚████║
╚══════╝   ╚═╝      ╚═╝   ╚══════╝╚═╝  ╚═══╝         
          
          
          
          
██████╗ ██╗   ██╗     █████╗ ███╗   ███╗███╗   ███╗██╗████████╗
██╔══██╗╚██╗ ██╔╝    ██╔══██╗████╗ ████║████╗ ████║██║╚══██╔══╝
██████╔╝ ╚████╔╝     ███████║██╔████╔██║██╔████╔██║██║   ██║   
██╔══██╗  ╚██╔╝      ██╔══██║██║╚██╔╝██║██║╚██╔╝██║██║   ██║   
██████╔╝   ██║       ██║  ██║██║ ╚═╝ ██║██║ ╚═╝ ██║██║   ██║   
╚═════╝    ╚═╝       ╚═╝  ╚═╝╚═╝     ╚═╝╚═╝     ╚═╝╚═╝   ╚═╝  

🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊🐊
""")   

# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# eternal life text

etrenal_life_text= (f"""

>>> Congratulation {dead_name} you win <<<<

𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀠 𓀤 𓀠 𓀠 𓀤 𓀠

███████╗████████╗███████╗██████╗ ███╗   ██╗ █████╗ ██╗         ██╗     ██╗███████╗███████╗    
██╔════╝╚══██╔══╝██╔════╝██╔══██╗████╗  ██║██╔══██╗██║         ██║     ██║██╔════╝██╔════╝    
█████╗     ██║   █████╗  ██████╔╝██╔██╗ ██║███████║██║         ██║     ██║█████╗  █████╗      
██╔══╝     ██║   ██╔══╝  ██╔══██╗██║╚██╗██║██╔══██║██║         ██║     ██║██╔══╝  ██╔══╝      
███████╗   ██║   ███████╗██║  ██║██║ ╚████║██║  ██║███████╗    ███████╗██║██║     ███████╗    
╚══════╝   ╚═╝   ╚══════╝╚═╝  ╚═╝╚═╝  ╚═══╝╚═╝  ╚═╝╚══════╝    ╚══════╝╚═╝╚═╝     ╚══════╝    
                                                                                        
𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀤 𓀠 𓀠 𓀠 𓀤 𓀠 𓀠 𓀤 
""")      
Mummification1()         
# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣  
# 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣 𓆣
# Out:
#  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣
#
#
# The Book of the Death is the map for Phraones to win the eternal life
# Your mission in this game is to become eternal
# but befor you have to die 𓀿 𓀿 𓀿
#
#
#  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣  𓂀 𓆣
#
# > Please press enter to continue...
#
# What's your name?  momo
# Please enter your age: 27
#
# 𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀
#
#
# Welcome Momo. I am the God  𓁛 RE 𓁛  SUN GOD 𓁛
#
# I will help you to make it to enternal life
#
# 𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀𓀠𓀀𓁵𓆣𓁫𓂀𓁣𓅔𓀍𓅊𓀍𓁢𓁚𓆣𓁟𓅊𓂀𓁡𓀤𓀠𓀀
#
#
#
# Momo, I know 27 year old is too young to die.
#
# But, if you want to become etrenal you have first to be
#
# 𓁀 𓁀 Mummifaied 𓁀 𓁀
#
#
# 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀 𓁀
# The door of the room will be open on 5 seconds...
#
# 5...𓀤...𓀤...𓀤 ...
#
# 4...𓀤...𓀤...𓀤 ...
#
# 3...𓀤...𓀤...𓀤 ...
#
# 2...𓀤...𓀤...𓀤 ...
#
# 1...𓀤...𓀤...𓀤  Let's Go!!!!
#
# > Please press enter to continue...
#
# ...
